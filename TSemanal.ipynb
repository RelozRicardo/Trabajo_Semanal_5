# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # TRABAJO SEMANAL
# #### Autor: RICARDO RELOZ

# %% [markdown]
# # EJERCICIO
# ## Diseñar un filtro pasabajos normalizado Bessel  para obtener un Retardo de Grupo  D(w) de 1 segundo.
#
# ### ws [rad/s] : 2.5
# ### wp [rad/s] : 1
# ### D [seg] : 1
# ### ⍺Max [dB] : 1
#
# ## 1. Utilizando el metodo de Storch ( pag. 403 del Schaumann) obtener la T(s) Bessel para N: 2, 3 y 4 normalizados para D = 1
# ## 2. Elegir la T(s) con el minimo orden que cumple con ⍺Max = 1 dB
# ## 3. Evaluar el Retardo de Grupo  D(2.5). Expresar en forma porcentual [%] el error o desviamiento respecto a D(0)
# ## 4. Sintetizar el circuito NORMALIZADO con estructuras Sallen-Key con K=1 ( real. negativa unitaria )
#
# <img src="./EJERCICIO.png" align="left" width="420" />
# <img src="./CIRCUITO.png" align="left" width="420" />
#
#
# BONUS
#     +10 💎 Simulación numérica en python
#     +10 💎 DESNORMALIZAR los componentes para obtener un D(1) = 200 microseg.
#     +10 💎 Simulación Circuital con los valores DESNORMALIZADOS y medir el  D(w)(*)
#     +10  🍺 Presentación en jupyter notebook

# %% [markdown]
# ## Ejercicio 1
# Primero planteo sacando las T($) con las N 2,3,4:
#
# <img src="./FOTO2.jpg" align="left" width="500" />
# <img src="./FOTO3.jpg" align="left" width="500" />

# %% [markdown]
# ## Ejercicio 2
# Para obtener la T($) con N orden minima e ideal para el circuito, fue tantear la atenuacion en wo
#
# <img src="./FOTO4.jpg" align="left" width="500" />

# %% [markdown]
# ## Ejercicio 3
# Para obtener el retardo desde T($) es sacar la parte real y compleja
# <img src="./FOTO5.jpg" align="left" width="600" />
# <img src="./FOTO6.jpg" align="left" width="600" />

# %% [markdown]
# ## Ejercicio 4
# Para poder hacer la Normalizacion, se tuvo que tomar en cuenta ciertos valores
# Para facilitar la escritura de calculos iguale los valores
# ### R1 = R2
# <img src="./FOTO1.jpg" align="left" width="600" />
# <img src="./FOTO7.jpg" align="left" width="600" />
# <img src="./FOTO8.jpg" align="left" width="600" />

# %% [markdown]
# ### DESNORMALIZACION DE CIRCUITO
#
# <img src="./FOTO9.jpg" align="left" width="600" />

# %% [markdown]
# ### Simulacion en SPYDER normalizada

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np


# Librería de TC2, esta la vas a usar mucho
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot
from pytc2.general import Chebyshev_polynomials, s, w, print_subtitle

import sympy as sp
from IPython.display import display


w0 = 1
qq1 = 1


my_tf = TransferFunction( [1], [1 , 6 , 15 , 15] )


plt.close('all')

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq1) )

pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq1)) #S plane pole/zero plot

GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq1))
# Out:
# /home/ricardo/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# (3,
#  <Axes: title={'center': 'Retardo de grupo'}, xlabel='Frecuencia angular [rad/seg]', ylabel='Retardo de grupo [seg]'>)

# %% [markdown]
# ## SIMULACION LTSPICE
#
# ### Circuito Normalizado
# <img src="./Circuito1.png" align="left" width="900" />
#
# ### Grafico respuesta en frecuencia del circuito
# <img src="./GRAFICO1.png" align="left" width="900" />
#
# ### Circuito Desnormalizado fp = 300Hz fs = 900Hz
# <img src="./Circuito2.png" align="left" width="900" />
#
# ### Grafico respuesta en frecuencia del circuito
# <img src="./GRAFICO2.png" align="left" width="900" />

# %% [markdown]
# ## Conclusiones y Reflexiones
# Tras calcular y analizar los valores de un filtro Bessel, he podido apreciar la eficacia y las ventajas de este tipo de filtro en aplicaciones que requieren una preservación precisa de la forma de la señal. El proceso de determinar el orden adecuado del filtro, así como la evaluación de la atenuación máxima y el retardo de grupo, demostró que un filtro Bessel de tercer orden cumple con las especificaciones de atenuación de 1 dB en la frecuencia de corte.
#
# El análisis del retardo de grupo confirmó que este filtro mantiene un retardo casi constante, minimizando la distorsión de fase y asegurando la integridad de las señales transitorias. Este ejercicio subraya la importancia de los filtros Bessel en sistemas de comunicaciones, procesamiento de señales de audio y otras aplicaciones críticas donde la fidelidad de la señal es primordial.
